# %% [markdown]
# <a href="https://colab.research.google.com/github/rojanridegreecollege/Python-mini-projects/blob/main/Data_base2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
importrandomimport random

# %%
a1=[]
a2=[]
a3=[]
a4=[]
a5=[]

# %%
for _ in range(1000):
    a1.append(random.randint(0,100))
    a2.append(random.randint(50,70))
    a3.append(random.randint(10,20))
    a4.append(random.randint(5,10))
    a5.append(random.randint(20,80))

# %%
a1
# Out:
# [72,
#  38,
#  95,
#  49,
#  34,
#  17,
#  55,
#  32,
#  35,
#  66,
#  81,
#  21,
#  9,
#  54,
#  98,
#  58,
#  77,
#  21,
#  27,
#  41,
#  93,
#  24,
#  70,
#  28,
#  27,
#  60,
#  47,
#  3,
#  20,
#  99,
#  68,
#  29,
#  76,
#  89,
#  91,
#  53,
#  88,
#  50,
#  84,
#  81,
#  81,
#  63,
#  87,
#  75,
#  94,
#  59,
#  95,
#  51,
#  67,
#  61,
#  85,
#  2,
#  75,
#  17,
#  40,
#  21,
#  46,
#  19,
#  63,
#  98,
#  45,
#  98,
#  55,
#  41,
#  29,
#  15,
#  53,
#  39,
#  77,
#  96,
#  99,
#  27,
#  72,
#  60,
#  1,
#  7,
#  45,
#  57,
#  77,
#  10,
#  21,
#  64,
#  56,
#  22,
#  86,
#  71,
#  8,
#  14,
#  14,
#  55,
#  96,
#  84,
#  98,
#  88,
#  74,
#  92,
#  60,
#  12,
#  11,
#  41,
#  53,
#  41,
#  3,
#  55,
#  16,
#  57,
#  94,
#  66,
#  64,
#  94,
#  26,
#  50,
#  71,
#  17,
#  17,
#  34,
#  68,
#  77,
#  53,
#  22,
#  47,
#  96,
#  43,
#  17,
#  10,
#  62,
#  3,
#  95,
#  73,
#  17,
#  11,
#  18,
#  96,
#  40,
#  93,
#  23,
#  1,
#  51,
#  92,
#  21,
#  4,
#  91,
#  91,
#  79,
# ...

# %%
df={
    'grade':a1,
    'weight':a2,
    'friends':a3,
    'cousins':a4,
    'projects':a5
}

# %%
df
# Out:
# {'grade': [72,
#   38,
#   95,
#   49,
#   34,
#   17,
#   55,
#   32,
#   35,
#   66,
#   81,
#   21,
#   9,
#   54,
#   98,
#   58,
#   77,
#   21,
#   27,
#   41,
#   93,
#   24,
#   70,
#   28,
#   27,
#   60,
#   47,
#   3,
#   20,
#   99,
#   68,
#   29,
#   76,
#   89,
#   91,
#   53,
#   88,
#   50,
#   84,
#   81,
#   81,
#   63,
#   87,
#   75,
#   94,
#   59,
#   95,
#   51,
#   67,
#   61,
#   85,
#   2,
#   75,
#   17,
#   40,
#   21,
#   46,
#   19,
#   63,
#   98,
#   45,
#   98,
#   55,
#   41,
#   29,
#   15,
#   53,
#   39,
#   77,
#   96,
#   99,
#   27,
#   72,
#   60,
#   1,
#   7,
#   45,
#   57,
#   77,
#   10,
#   21,
#   64,
#   56,
#   22,
#   86,
#   71,
#   8,
#   14,
#   14,
#   55,
#   96,
#   84,
#   98,
#   88,
#   74,
#   92,
#   60,
#   12,
#   11,
#   41,
#   53,
#   41,
#   3,
#   55,
#   16,
#   57,
#   94,
#   66,
#   64,
#   94,
#   26,
#   50,
#   71,
#   17,
#   17,
#   34,
#   68,
#   77,
#   53,
#   22,
#   47,
#   96,
#   43,
#   17,
# ...

# %%
pip install pandas

# %%
import  pandas as pd

# %%
df1 = pd.DataFrame(df)

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       72      65       10        8        62
# 1       38      62       17        7        79
# 2       95      52       15        5        37
# 3       49      70       20       10        40
# 4       34      56       14        9        60
# ..     ...     ...      ...      ...       ...
# 995     64      61       12       10        50
# 996      7      59       19       10        50
# 997     93      60       17       10        26
# 998      4      70       10       10        40
# 999     51      56       19       10        55
#
# [1000 rows x 5 columns]

# %%
df1.describe ()
# Out:
#              grade       weight      friends      cousins     projects
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     51.038000    59.909000    15.010000     7.579000    49.042000
# std      29.573826     5.908606     3.247529     1.706068    17.936275
# min       0.000000    50.000000    10.000000     5.000000    20.000000
# 25%      25.000000    55.000000    12.000000     6.000000    34.000000
# 50%      51.000000    60.000000    15.000000     8.000000    49.000000
# 75%      76.000000    65.000000    18.000000     9.000000    64.000000
# max     100.000000    70.000000    20.000000    10.000000    80.000000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
df1['grade'].count()
# Out:
# 1000

# %%
friend15=df1['friends']>15

# %%
df1[friend15]
# Out:
#      grade  weight  friends  cousins  projects
# 1       38      62       17        7        79
# 3       49      70       20       10        40
# 8       35      56       16       10        28
# 9       66      59       16        8        29
# 10      81      57       18        6        77
# ..     ...     ...      ...      ...       ...
# 990     28      68       20       10        52
# 994     83      52       18       10        23
# 996      7      59       19       10        50
# 997     93      60       17       10        26
# 999     51      56       19       10        55
#
# [458 rows x 5 columns]

# %%
grade50=df1['grade']>50

# %%
df1[grade50]
# Out:
#      grade  weight  friends  cousins  projects
# 0       72      65       10        8        62
# 2       95      52       15        5        37
# 6       55      65       10        8        22
# 9       66      59       16        8        29
# 10      81      57       18        6        77
# ..     ...     ...      ...      ...       ...
# 993     84      56       12        9        51
# 994     83      52       18       10        23
# 995     64      61       12       10        50
# 997     93      60       17       10        26
# 999     51      56       19       10        55
#
# [508 rows x 5 columns]

# %%
df1[friend15&grade50].value_counts()
# Out:
# grade  weight  friends  cousins  projects
# 51     51      18       7        63          1
# 84     61      20       7        35          1
# 85     54      16       7        25          1
#                20       8        62          1
#        66      17       7        32          1
#                                             ..
# 68     69      16       6        77          1
#                18       9        64          1
# 69     52      16       8        73          1
#        64      18       5        61          1
# 100    56      20       9        78          1
# Name: count, Length: 228, dtype: int64

# %%
df1[friend15&grade50]['weight'].value_counts()
# Out:
# weight
# 59    18
# 58    17
# 50    14
# 65    13
# 56    13
# 57    12
# 52    12
# 62    12
# 55    12
# 54    12
# 64    11
# 60    11
# 61    11
# 67     9
# 51     9
# 69     8
# 66     8
# 53     7
# 70     7
# 68     7
# 63     5
# Name: count, dtype: int64

# %%
df1[friend15&grade50]['friends']
# Out:
# 9      16
# 10     18
# 13     20
# 14     19
# 20     18
#        ..
# 981    17
# 982    18
# 994    18
# 997    17
# 999    19
# Name: friends, Length: 228, dtype: int64

# %%
df1[friend15&grade50]['weight'].value_counts()
# Out:
# weight
# 59    18
# 58    17
# 50    14
# 65    13
# 56    13
# 57    12
# 52    12
# 62    12
# 55    12
# 54    12
# 64    11
# 60    11
# 61    11
# 67     9
# 51     9
# 69     8
# 66     8
# 53     7
# 70     7
# 68     7
# 63     5
# Name: count, dtype: int64

# %%
from matplotlib import pyplot as pit

# %%
df1[friend15&grade50].plot()
# Out:
# <Axes: >

# %%
# %matplotlib inline

# %%
df1[friend15&grade50].plot()
# Out:
# <Axes: >

# %%
df1[friend15&grade50].plot(x = 'grade',y= 'projects',kind='pie')
# Out:
# <Axes: ylabel='projects'>

# %%
fdf=df1[friend15&grade50]

# %%
fdf
# Out:
#      grade  weight  friends  cousins  projects
# 9       66      59       16        8        29
# 10      81      57       18        6        77
# 13      54      60       20        6        32
# 14      98      54       19        8        20
# 20      93      53       18        9        33
# ..     ...     ...      ...      ...       ...
# 981     99      66       17        7        27
# 982     91      53       18        6        68
# 994     83      52       18       10        23
# 997     93      60       17       10        26
# 999     51      56       19       10        55
#
# [228 rows x 5 columns]

# %%
df1
# Out:
#      grade  weight  friends  cousins  projects
# 0       72      65       10        8        62
# 1       38      62       17        7        79
# 2       95      52       15        5        37
# 3       49      70       20       10        40
# 4       34      56       14        9        60
# ..     ...     ...      ...      ...       ...
# 995     64      61       12       10        50
# 996      7      59       19       10        50
# 997     93      60       17       10        26
# 998      4      70       10       10        40
# 999     51      56       19       10        55
#
# [1000 rows x 5 columns]

# %%
dfdf1.to_csv('/Feb6TestData.csv
