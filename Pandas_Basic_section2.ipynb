# %% [markdown]
# <a href="https://colab.research.google.com/github/rojanridegreecollege/Python-mini-projects/blob/main/Pandas_Basic_section2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import pandas as pd
age=[]
height=[]
weight=[]
speed=[]
for _ in range(100):
 age.append(random.randint(0,100))
 height.append (random.randint(0,100))
 weight.append(random.randint(0,100))
 speed.append (random. randint (0,100))
 idata = {'age':age,'height': height,'weight': weight,'speed': speed}

# %%
idata
# Out:
# {'age': [77,
#   55,
#   54,
#   33,
#   44,
#   82,
#   83,
#   67,
#   29,
#   64,
#   5,
#   8,
#   86,
#   84,
#   48,
#   68,
#   53,
#   65,
#   96,
#   49,
#   93,
#   88,
#   29,
#   83,
#   70,
#   53,
#   21,
#   29,
#   6,
#   74,
#   45,
#   64,
#   39,
#   10,
#   79,
#   26,
#   12,
#   2,
#   17,
#   91,
#   62,
#   30,
#   61,
#   53,
#   34,
#   48,
#   86,
#   31,
#   99,
#   42,
#   56,
#   27,
#   49,
#   53,
#   85,
#   36,
#   1,
#   42,
#   79,
#   56,
#   6,
#   43,
#   81,
#   66,
#   26,
#   64,
#   51,
#   34,
#   17,
#   91,
#   9,
#   88,
#   32,
#   29,
#   25,
#   17,
#   89,
#   57,
#   85,
#   90,
#   46,
#   61,
#   100,
#   30,
#   25,
#   61,
#   34,
#   56,
#   6,
#   24,
#   24,
#   44,
#   98,
#   59,
#   66,
#   11,
#   94,
#   22,
#   63,
#   70],
#  'height': [36,
#   23,
#   51,
#   4,
#   7,
#   30,
#   1,
#   8,
#   72,
#   83,
#   68,
#   25,
#   43,
#   72,
#   33,
#   11,
#   56,
#   52,
#   34,
#   63,
#   65,
#   51,
#   88,
#   73,
#   75,
#   61,
#   16,
#   5,
#   8,
#   18,
#   48,
#   46,
#   56,
#   59,
#   73,
#   14,
#   72,
#   58,
#   80,
#   95,
#   57,
#   93,
#   52,
#   22,
#   6,
#   88,
#   63,
#   53,
#   85,
#   31,
#   41,
#   10,
#   69,
#   59,
#   37,
#   9,
#   41,
#   81,
#   8,
#   81,
#   42,
#   7,
#   68,
#   84,
#   93,
#   88,
#   20,
#   51,
#   17,
#   29,
#   78,
#   23,
#   49,
#   100,
#   39,
#   46,
#   17,
#   36,
#   91,
#   57,
#   67,
#   56,
#   85,
#   56,
#   72,
#   57,
#   96,
#   10,
#   71,
#   59,
#   49,
#   56,
#   16,
#   23,
#   80,
#   37,
#   38,
#   49,
#   80,
#   38],
#  'weight': [77,
#   74,
#   100,
#   60,
#   22,
#   64,
#   47,
#   99,
#   9,
#   97,
#   12,
#   87,
#   12,
#   59,
#   22,
#   11,
#   1,
#   37,
#   79,
#   5,
#   100,
#   93,
#   81,
#   98,
#   35,
#   76,
#   0,
#   0,
#   49,
#   18,
#   54,
#   71,
#   69,
#   78,
#   93,
#   47,
#   39,
#   92,
#   34,
#   74,
#   68,
#   13,
#   5,
#   11,
#   73,
#   37,
#   14,
#   100,
#   90,
#   21,
#   48,
#   36,
#   64,
#   26,
#   23,
#   44,
#   35,
#   36,
#   2,
#   42,
#   16,
#   58,
#   9,
#   3,
#   50,
#   99,
#   53,
#   97,
#   79,
#   70,
#   96,
#   92,
#   65,
#   96,
#   40,
#   58,
#   0,
#   53,
#   9,
#   48,
#   18,
#   100,
#   98,
#   95,
#   27,
#   38,
#   10,
#   60,
#   5,
#   66,
#   47,
#   47,
#   95,
#   19,
#   2,
#   56,
#   33,
#   30,
#   76,
#   63],
#  'speed': [27,
#   78,
#   79,
#   29,
#   31,
#   26,
#   55,
#   1,
#   75,
#   89,
#   13,
#   16,
#   57,
#   21,
#   5,
#   86,
#   6,
#   96,
#   28,
#   20,
#   21,
#   11,
#   52,
#   40,
#   71,
#   41,
#   16,
#   6,
#   31,
#   76,
#   12,
#   84,
#   19,
#   71,
#   62,
#   54,
#   70,
#   95,
#   32,
#   75,
#   100,
#   58,
#   0,
#   36,
#   51,
#   65,
#   65,
#   36,
#   73,
#   43,
#   2,
#   4,
#   86,
#   73,
#   41,
#   90,
#   51,
#   18,
#   4,
#   18,
#   18,
#   85,
#   14,
#   1,
#   28,
#   84,
#   81,
#   77,
#   66,
#   13,
#   78,
#   54,
#   8,
#   74,
#   83,
#   81,
#   36,
#   7,
#   69,
#   46,
#   90,
#   15,
#   27,
#   89,
#   13,
#   81,
#   18,
#   49,
#   93,
#   90,
#   24,
#   42,
#   77,
#   13,
#   44,
#   41,
#   36,
#   38,
#   23,
#   52]}

# %%
df1=pd.DataFrame(idata)

# %%
df1.describe()
# Out:
#               age     height      weight       speed
# count  100.000000  100.00000  100.000000  100.000000
# mean    52.160000   49.31000   45.870000   50.510000
# std     30.844255   27.63788   30.069164   25.907955
# min      1.000000    0.00000    0.000000    2.000000
# 25%     26.500000   27.50000   16.000000   31.750000
# 50%     53.000000   49.00000   47.000000   50.000000
# 75%     77.250000   70.25000   73.250000   72.000000
# max     99.000000   98.00000   99.000000  100.000000

# %%
df1[['age','height']]
# Out:
#     age  height
# 0     7      95
# 1     5      23
# 2    97      61
# 3    44      64
# 4    75      51
# ..  ...     ...
# 95   44      90
# 96   41      46
# 97   74      64
# 98   95      41
# 99   87      81
#
# [100 rows x 2 columns]

# %%
df1.loc[[0,3],['age','height']]
# Out:
#    age  height
# 0    7      95
# 3   44      64

# %%
df2=df1[['age','height']]

# %%
df1.sort_index(ascending=True)
# Out:
#     age  height  weight  speed
# 0     7      95      17     61
# 1     5      23      93      9
# 2    97      61      35     47
# 3    44      64      10     35
# 4    75      51       5     52
# ..  ...     ...     ...    ...
# 95   44      90      62     58
# 96   41      46      24     83
# 97   74      64      16     15
# 98   95      41      64     80
# 99   87      81      75     44
#
# [100 rows x 4 columns]

# %%
df1[0::2].describe()
# Out:
#              age     height     weight      speed
# count  50.000000  50.000000  50.000000  50.000000
# mean   51.960000  48.820000  44.980000  53.100000
# std    29.424383  27.467747  28.941524  25.554464
# min     6.000000   1.000000   0.000000   2.000000
# 25%    32.000000  29.000000  17.500000  36.500000
# 50%    50.500000  46.500000  46.500000  52.500000
# 75%    76.500000  64.500000  70.250000  73.500000
# max    99.000000  98.000000  92.000000  99.000000

# %%
# filter
df1['weight']>50
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
#       ...
# 95     True
# 96    False
# 97    False
# 98     True
# 99     True
# Name: weight, Length: 100, dtype: bool

# %%
# filter
filter1=df1['weight']>50

# %%
df1[filter1]
# Out:
#     age  height  weight  speed
# 1     5      23      93      9
# 10   73      46      87     34
# 11   88      50      73     41
# 14   15      32      64     59
# 15   84      87      87     32
# 16   64      89      75     25
# 17    3      10      74     68
# 18   49       9      76      6
# 19   77      17      70     41
# 21   75      19      62     51
# 22   92      66      72     50
# 23   76      48      64     70
# 24   66      54      51     94
# 26   19      19      75     50
# 31   22      38      78     72
# 32    7      97      91     31
# 34    7      96      84     85
# 39   95      42      75     13
# 40   32      44      57     38
# 41   54       8      86     79
# 42   88      23      92     75
# 50   43      36      84     42
# 51   77      93      85     36
# 52   41      16      91     79
# 53   32       0      82     56
# 56   37       2      75     82
# 58   15      45      92      9
# 60   77      96      53     72
# 61   37      26      99     21
# 63    1      74      52     92
# 65   99      77      79     49
# 66   94      16      63     76
# 67   38      46      75     70
# 71   28      30      98     57
# 73   68      69      51     83
# 74   13      98      72     90
# 75    3      96      57     16
# 76    7       1      61     92
# 79    6      47      70     16
# 81   18      37      97     87
# 82    6      43      65      2
# 83   94      79      64     38
# 89   11      84      57      8
# 94   85      62      55     67
# 95   44      90      62     58
# 98   95      41      64     80
# 99   87      81      75     44

# %%
df1.loc[filter1]
# Out:
#     age  height  weight  speed
# 1     5      23      93      9
# 10   73      46      87     34
# 11   88      50      73     41
# 14   15      32      64     59
# 15   84      87      87     32
# 16   64      89      75     25
# 17    3      10      74     68
# 18   49       9      76      6
# 19   77      17      70     41
# 21   75      19      62     51
# 22   92      66      72     50
# 23   76      48      64     70
# 24   66      54      51     94
# 26   19      19      75     50
# 31   22      38      78     72
# 32    7      97      91     31
# 34    7      96      84     85
# 39   95      42      75     13
# 40   32      44      57     38
# 41   54       8      86     79
# 42   88      23      92     75
# 50   43      36      84     42
# 51   77      93      85     36
# 52   41      16      91     79
# 53   32       0      82     56
# 56   37       2      75     82
# 58   15      45      92      9
# 60   77      96      53     72
# 61   37      26      99     21
# 63    1      74      52     92
# 65   99      77      79     49
# 66   94      16      63     76
# 67   38      46      75     70
# 71   28      30      98     57
# 73   68      69      51     83
# 74   13      98      72     90
# 75    3      96      57     16
# 76    7       1      61     92
# 79    6      47      70     16
# 81   18      37      97     87
# 82    6      43      65      2
# 83   94      79      64     38
# 89   11      84      57      8
# 94   85      62      55     67
# 95   44      90      62     58
# 98   95      41      64     80
# 99   87      81      75     44

# %%
filter2=df1['age']>50

# %%
df1[filter1&filter2]
# Out:
#     age  height  weight  speed
# 10   73      46      87     34
# 11   88      50      73     41
# 15   84      87      87     32
# 16   64      89      75     25
# 19   77      17      70     41
# 21   75      19      62     51
# 22   92      66      72     50
# 23   76      48      64     70
# 24   66      54      51     94
# 39   95      42      75     13
# 41   54       8      86     79
# 42   88      23      92     75
# 51   77      93      85     36
# 60   77      96      53     72
# 65   99      77      79     49
# 66   94      16      63     76
# 73   68      69      51     83
# 83   94      79      64     38
# 94   85      62      55     67
# 98   95      41      64     80
# 99   87      81      75     44

# %%
df1.loc[filter1&filter2 ]
# Out:
#     age  height  weight  speed
# 10   73      46      87     34
# 11   88      50      73     41
# 15   84      87      87     32
# 16   64      89      75     25
# 19   77      17      70     41
# 21   75      19      62     51
# 22   92      66      72     50
# 23   76      48      64     70
# 24   66      54      51     94
# 39   95      42      75     13
# 41   54       8      86     79
# 42   88      23      92     75
# 51   77      93      85     36
# 60   77      96      53     72
# 65   99      77      79     49
# 66   94      16      63     76
# 73   68      69      51     83
# 83   94      79      64     38
# 94   85      62      55     67
# 98   95      41      64     80
# 99   87      81      75     44
